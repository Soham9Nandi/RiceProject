# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/content/ImajeJ - rice project.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0   AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  \
# 0         1.0  199.0    198.023   0.868  198.023   552.0   660.0    0.868
# 1         2.0   64.0     63.285 -84.560   63.285   654.0   633.0   95.440
# 2         3.0  143.0    142.302 -18.435  142.302   588.0   630.0  161.565
# 3         4.0  143.0    141.510  21.125  141.510   588.0   681.0   21.125
# 4         NaN    NaN        NaN     NaN      NaN     NaN     NaN      NaN
#
#    MINFERET   LENGTH  ... Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0       0.0  198.023  ...         NaN          NaN          NaN          NaN
# 1       0.0   63.285  ...         NaN          NaN          NaN          NaN
# 2       0.0  142.302  ...         NaN          NaN          NaN          NaN
# 3       0.0  141.510  ...         NaN          NaN          NaN          NaN
# 4       NaN      NaN  ...         NaN          NaN          NaN          NaN
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 21
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 22 columns]

# %%
dataset = dataset.dropna(how='all',axis=1)

# %%
dataset.head()
# Out:
#    Unnamed: 0   AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  \
# 0         1.0  199.0    198.023   0.868  198.023   552.0   660.0    0.868
# 1         2.0   64.0     63.285 -84.560   63.285   654.0   633.0   95.440
# 2         3.0  143.0    142.302 -18.435  142.302   588.0   630.0  161.565
# 3         4.0  143.0    141.510  21.125  141.510   588.0   681.0   21.125
# 4         NaN    NaN        NaN     NaN      NaN     NaN     NaN      NaN
#
#    MINFERET   LENGTH   TYPE
# 0       0.0  198.023  First
# 1       0.0   63.285  First
# 2       0.0  142.302  First
# 3       0.0  141.510  First
# 4       NaN      NaN  First

# %%
dataset = dataset.dropna()

# %%
dataset.head()
# Out:
#    Unnamed: 0   AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  \
# 0         1.0  199.0    198.023   0.868  198.023   552.0   660.0    0.868
# 1         2.0   64.0     63.285 -84.560   63.285   654.0   633.0   95.440
# 2         3.0  143.0    142.302 -18.435  142.302   588.0   630.0  161.565
# 3         4.0  143.0    141.510  21.125  141.510   588.0   681.0   21.125
# 5         1.0  125.0    123.584  -5.572  123.584   486.0   558.0  174.428
#
#    MINFERET   LENGTH   TYPE
# 0       0.0  198.023  First
# 1       0.0   63.285  First
# 2       0.0  142.302  First
# 3       0.0  141.510  First
# 5       0.0  123.584  First

# %%
dataset = dataset.drop(columns = 'Unnamed: 0')

# %%
dataset.head()
# Out:
#     AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  MINFERET  \
# 0  199.0    198.023   0.868  198.023   552.0   660.0    0.868       0.0
# 1   64.0     63.285 -84.560   63.285   654.0   633.0   95.440       0.0
# 2  143.0    142.302 -18.435  142.302   588.0   630.0  161.565       0.0
# 3  143.0    141.510  21.125  141.510   588.0   681.0   21.125       0.0
# 5  125.0    123.584  -5.572  123.584   486.0   558.0  174.428       0.0
#
#     LENGTH   TYPE
# 0  198.023  First
# 1   63.285  First
# 2  142.302  First
# 3  141.510  First
# 5  123.584  First

# %%
#identifying all the numeric columns
numeric = dataset._get_numeric_data()
TYPE = dataset['TYPE']
print(numeric.head())
print("Numeric column: ",end =" ")
print(numeric.columns)
print(len(numeric.columns))

numeric.describe()
# Out:
#     AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  MINFERET  \
# 0  199.0    198.023   0.868  198.023   552.0   660.0    0.868       0.0
# 1   64.0     63.285 -84.560   63.285   654.0   633.0   95.440       0.0
# 2  143.0    142.302 -18.435  142.302   588.0   630.0  161.565       0.0
# 3  143.0    141.510  21.125  141.510   588.0   681.0   21.125       0.0
# 5  125.0    123.584  -5.572  123.584   486.0   558.0  174.428       0.0
#
#     LENGTH
# 0  198.023
# 1   63.285
# 2  142.302
# 3  141.510
# 5  123.584
# Numeric column:  Index(['AREA', 'PERIMETER', 'ANGLE', 'FERET', 'FERETX', 'FERETY', 'FERETZ',
#        'MINFERET', 'LENGTH'],
#       dtype='object')
# 9
#                 AREA    PERIMETER       ANGLE       FERET      FERETX  \
# count     872.000000   872.000000  872.000000  872.000000  872.000000
# mean      312.094037   105.900428  -20.286599   53.571825  404.438847
# std      7094.719863    96.142216   83.179411   46.309612  199.344017
# min        16.000000    14.560000 -178.831000 -133.264000    0.000000
# 25%        42.750000    43.188500  -90.000000   25.632000  300.000000
# 50%        74.000000    81.498000  -14.931000   59.774000  441.000000
# 75%        94.000000   116.188500   26.994750   84.853000  576.000000
# max    209572.000000  1834.000000  180.000000  649.419000  735.000000
#
#            FERETY      FERETZ    MINFERET      LENGTH
# count  872.000000  872.000000  872.000000  872.000000
# mean   521.138761  214.642552    0.506881   69.558569
# std     95.941143  243.039187   14.666047   30.996390
# min      0.000000    0.000000    0.000000    0.000000
# 25%    462.000000   52.054500    0.000000   40.951000
# 50%    522.000000  125.538000    0.000000   72.529000
# 75%    579.000000  176.451000    0.000000   93.072250
# max    849.000000  885.000000  433.000000  198.023000

# %%
#creating histogram for better analysis
num_hist = numeric.hist(layout=(3,5),figsize = (20,10))
plt.show()

# %%
#features of each type
grouped_type = dataset.groupby('TYPE')

for col in numeric.columns:
  fig,ax = plt.subplots()

  for i,d in grouped_type:
    d[col].hist(alpha=0.4, ax=ax, label=i, figsize=(10,4))
    ax.set_title(col)

  ax.legend()
  plt.show()

# %%
grouped_type.mean()
# Out:
#                AREA   PERIMETER      ANGLE      FERET      FERETX      FERETY  \
# TYPE
# Fifth     82.859375   69.104047 -30.437828  66.953063  470.250000  620.953125
# First   1121.560000   81.758507 -56.430180  75.939860  583.790000  513.715000
# Fourth    50.517857   49.582929 -55.471009  49.582929  586.991071  515.339286
# Second    67.653061   66.681571 -54.269658  66.681571  417.887755  470.846939
# Sixth     86.710000  233.853140  85.758375  12.207390   85.758375  527.770000
# Third     62.710000   61.773090 -47.579260  61.773090  410.160000  563.910000
#
#             FERETZ      MINFERET     LENGTH
# TYPE
# Fifth    79.182656  1.406250e-01  65.072797
# First    88.260735  2.165000e+00  72.692765
# Fourth   90.778991  2.458750e-16  49.582929
# Second   94.505852  5.189592e-16  66.681571
# Sixth   632.380000  5.419600e-16  85.758375
# Third    92.820740  2.131200e-16  61.773090

# %%
grouped_type.std()
# Out:
#                 AREA   PERIMETER      ANGLE      FERET     FERETX      FERETY  \
# TYPE
# Fifth     130.159715   38.561359  49.513674  30.944564  75.333544   78.521139
# First   14813.768342  127.748337  71.025977  49.810633  85.338380  109.220784
# Fourth     24.518051   24.530366  51.574072  24.530366  60.852131  106.495574
# Second     27.534445   27.531981  80.673606  27.531981  66.677930   79.776656
# Sixth      26.328346    9.975398  26.299684  47.927601  26.299684   64.309687
# Third      38.452987   38.431692  46.000114  38.431692  77.606326   77.338048
#
#             FERETZ      MINFERET     LENGTH
# TYPE
# Fifth    57.904423  1.125000e+00  31.303244
# First    64.067020  3.061772e+01  29.100290
# Fourth   58.245121  8.102504e-16  24.530366
# Second   67.202691  1.240444e-15  27.531981
# Sixth   133.518770  1.629269e-15  26.299684
# Third    56.354661  7.424395e-16  38.431692

# %%
grouped_type.min()
# Out:
#         AREA  PERIMETER    ANGLE    FERET   FERETX  FERETY   FERETZ  MINFERET  \
# TYPE
# Fifth   27.0     25.807 -101.310   25.807  315.000   492.0    0.000       0.0
# First   16.0     14.560 -178.831   14.560    0.000     0.0    0.000       0.0
# Fourth  19.0     18.000 -174.644   18.000  423.000   276.0    0.000       0.0
# Second  16.0     15.297 -177.955   15.297  234.000   252.0    0.000       0.0
# Sixth   25.0    196.344   24.331 -133.264   24.331   364.0  332.000       0.0
# Third   16.0     15.297 -127.875   15.297  255.000   369.0    1.507       0.0
#
#         LENGTH
# TYPE
# Fifth    0.000
# First    0.000
# Fourth  18.000
# Second  15.297
# Sixth   24.331
# Third   15.297

# %%
grouped_type.max()
# Out:
#             AREA  PERIMETER    ANGLE    FERET   FERETX  FERETY   FERETZ  \
# TYPE
# Fifth     1080.0    258.000   90.000  120.337  645.000   849.0  178.363
# First   209572.0   1834.000  180.000  649.419  735.000   738.0  178.493
# Fourth     110.0    109.037   20.556  109.037  698.000   744.0  176.055
# Second     117.0    115.918  180.000  115.918  612.000   633.0  178.452
# Sixth      159.0    253.501  157.835  116.565  157.835   726.0  885.000
# Third      128.0    126.606   45.000  126.606  636.000   717.0  176.820
#
#             MINFERET   LENGTH
# TYPE
# Fifth   9.000000e+00  119.775
# First   4.330000e+02  198.023
# Fourth  3.550000e-15  109.037
# Second  7.110000e-15  115.918
# Sixth   7.110000e-15  157.835
# Third   3.550000e-15  126.606

# %%
org = dataset['TYPE']

# %%
fig = plt.figure(figsize = (20,10))
plt.bar(height=dataset['TYPE'].value_counts().values,x=dataset['TYPE'].value_counts().index)
plt.show()

# %%
#packages for correlation analysis
import seaborn as sns
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler
from imblearn.over_sampling import SMOTE

# %%
dataset['TYPE'] = LabelEncoder().fit_transform(dataset['TYPE'])
corr = dataset.corr()
sns.heatmap(data=corr)
# Out:
# <Axes: >

# %%
#Define Features(Indedpendent Variables)
x = dataset.iloc[:,1:-1].values

# %%
#Define target
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf = RandomForestClassifier(random_state = 0)
classifier_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred = classifier_rf.predict(x_test)
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score,confusion_matrix
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average = 'micro')
prec = precision_score(y_test, y_pred, average='micro')
rec = recall_score(y_test, y_pred,average='micro')

# %%
results = pd.DataFrame([["Logistic Regression", acc, f1, prec, rec]],
                       columns = ['Model','Accuracy','F1 Score', 'Precision','Recall'])
results
# Out:
#                  Model  Accuracy  F1 Score  Precision    Recall
# 0  Logistic Regression  0.748571  0.748571   0.748571  0.748571

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 6,  4,  0,  0,  0,  3],
#        [ 1, 28,  3,  1,  0,  0],
#        [ 1,  9, 13,  0,  0,  3],
#        [ 3,  5,  0, 35,  0,  1],
#        [ 0,  0,  0,  0, 38,  0],
#        [ 1,  1,  0,  8,  0, 11]])

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier_rf, X= x_train, y=y_train, cv = 10)
print("Accuracy is {:.2f}%".format(accuracies.mean()*100))
print("Standard Devation is {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy is 74.88%
# Standard Devation is 3.72%
